# %% [markdown]
# # 🚗 Road Accident Data Analysis
#
# This notebook performs an Exploratory Data Analysis (EDA) on a road accident dataset to identify high-risk regions, seasonal trends, and severity patterns.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style="darkgrid")
plt.rcParams.update({'figure.figsize': (10, 6), 'font.size': 12})

# %% [markdown]
# ## 2. Load the Cleaned Dataset

# %%
# Load the processed data
df = pd.read_csv('../dataset/processed/accident_cleaned.csv')
df.head()
# Out:
#   accident_index  location_easting_osgr  location_northing_osgr  longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     latitude  police_force  accident_severity  number_of_vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    number_of_casualties        date  ...           weather_condition  \
# ...

# %% [markdown]
# ## 3. Analysis: Accidents by Region

# %%
top_regions = df['region'].value_counts().head(10)
sns.barplot(x=top_regions.values, y=top_regions.index, palette='viridis')
plt.title('Top 10 High-Risk Regions', fontsize=16, fontweight='bold')
plt.xlabel('Number of Accidents')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# ## 4. Analysis: Accident Severity

# %%
sns.countplot(data=df, x='accident_severity', palette='rocket')
plt.title('Distribution of Accident Severity', fontsize=16, fontweight='bold')
plt.xlabel('Severity Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 5. Analysis: Monthly Trend

# %%
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
monthly_counts = df['month'].value_counts().reindex(months_order).fillna(0)
sns.lineplot(x=monthly_counts.index, y=monthly_counts.values, marker='o', color='crimson')
plt.title('Monthly Accident Trends', fontsize=16, fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 6. Analysis: Day of Week Trend

# %%
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_counts = df['day_of_week_extracted'].value_counts().reindex(days_order).fillna(0)
sns.barplot(x=day_counts.index, y=day_counts.values, palette='coolwarm')
plt.title('Accidents by Day of the Week', fontsize=16, fontweight='bold')
plt.show()
