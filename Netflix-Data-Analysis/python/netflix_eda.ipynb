# %% [markdown]
# # 🎬 Netflix Data Analysis - Exploratory Data Analysis (EDA)
#
# This notebook performs an end-to-end EDA on the Netflix Movies and TV Shows dataset. We will explore content distribution, genres, release trends, top producing countries, and rating distributions.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set visual styles
sns.set_theme(style="darkgrid")
plt.rcParams.update({'figure.figsize': (10, 6), 'font.size': 12})

# %% [markdown]
# ## 2. Load the Cleaned Dataset

# %%
# Ensure the data_cleaning.py script has been run to generate this file.
df = pd.read_csv('../dataset/processed/netflix_cleaned.csv')
df.head()

# %% [markdown]
# ## 3. Analysis 1: Content Type Distribution

# %%
plt.figure()
ax = sns.countplot(data=df, x='type', palette='Set2')
plt.title('Content Type Distribution on Netflix', fontsize=16, fontweight='bold')
plt.xlabel('Content Type', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Add count labels above bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')
plt.show()

# %% [markdown]
# **Insight**: Movies dominate the Netflix catalog compared to TV Shows.

# %% [markdown]
# ## 4. Analysis 2: Most Common Genres

# %%
genres = df['listed_in'].str.split(',').explode().str.strip()
top_genres = genres.value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(y=top_genres.index, x=top_genres.values, palette='viridis')
plt.title('Top 10 Most Common Genres on Netflix', fontsize=16, fontweight='bold')
plt.xlabel('Count', fontsize=12)
plt.ylabel('Genre', fontsize=12)
plt.show()

# %% [markdown]
# **Insight**: International Movies and Dramas are the top two most popular genres.

# %% [markdown]
# ## 5. Analysis 3: Yearly Release Trend

# %%
yearly_trend = df['release_year'].value_counts().sort_index()
recent_trend = yearly_trend[yearly_trend.index >= 2000]

plt.figure(figsize=(12, 6))
sns.lineplot(x=recent_trend.index, y=recent_trend.values, marker='o', color='crimson', linewidth=2)
plt.title('Netflix Content Release Trend (2000 - Present)', fontsize=16, fontweight='bold')
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)
plt.show()

# %% [markdown]
# **Insight**: Content production increased rapidly after 2015, peaking around 2018-2019.

# %% [markdown]
# ## 6. Analysis 4: Top Producing Countries

# %%
countries = df['country'].str.split(',').explode().str.strip()
countries = countries[countries != 'Unknown']
top_countries = countries.value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='mako')
plt.title('Top 10 Content Producing Countries', fontsize=16, fontweight='bold')
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.show()

# %% [markdown]
# **Insight**: The United States and India are the largest producers of Netflix content.

# %% [markdown]
# ## 7. Analysis 5: Rating Distribution

# %%
plt.figure(figsize=(12, 6))
ratings_order = df['rating'].value_counts().index
sns.countplot(data=df, x='rating', order=ratings_order, palette='rocket')
plt.title('Distribution of Content Ratings', fontsize=16, fontweight='bold')
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight**: TV-MA (Mature Audiences) is the most frequent rating.
